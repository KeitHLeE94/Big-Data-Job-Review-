# %% [markdown]
# # Collocation(연어)

# %%
from nltk.corpus import gutenberg

gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
corpus = gutenberg.open('austen-emma.txt').read()

# %%
from nltk import regexp_tokenize, Text

# %%
pattern = r'([a-zA-Z0-9]+)+'

# %%
tokens = regexp_tokenize(corpus, pattern)
len(tokens)
# Out:
# 161980

# %%
en = Text(tokens)
type(en)
# Out:
# nltk.text.Text

# %% [markdown]
# 영문 corpus를 정규식 형태로 주어진 패턴으로 tokenize하여 영어, 숫자만 뽑아낸 후 Text 객체에 저장.

# %%
from konlpy.corpus import kolaw

kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
corpus = kolaw.open('constitution.txt').read()

# %%
from konlpy.tag import Kkma

# %%
kkma = Kkma()

# %%
tokens = kkma.morphs(corpus)

# %% [markdown]
# morphs: 한글 corpus를 형태소 단위로 분석.

# %%
tokens[:5]
# Out:
# ['대한민국', '헌법', '유구', '하', 'ㄴ']

# %%
ko = Text(tokens)

# %% [markdown]
# 한글 corpus를 형태소 단위로 tokenize한 후 Text 객체에 저장.

# %%
sentence = 'The little yellow dog barked at the Persian cat'

# %%
tokens = sentence.split(' ')
tokens
# Out:
# ['The', 'little', 'yellow', 'dog', 'barked', 'at', 'the', 'Persian', 'cat']

# %%
import nltk

# %%
nltk.pos_tag(tokens)
# Out:
# [('The', 'DT'),
#  ('little', 'JJ'),
#  ('yellow', 'JJ'),
#  ('dog', 'NN'),
#  ('barked', 'VBD'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Persian', 'JJ'),
#  ('cat', 'NN')]

# %% [markdown]
# nltk 모듈을 활용하여 각 단어들의 품사 분석.

# %%
entags = nltk.pos_tag(tokens)

# %%
sentence = '내 친구는 잠을 많이 잔다.'

# %%
kkma.pos(sentence)
# Out:
# [('내', 'NP'),
#  ('친구', 'NNG'),
#  ('는', 'JX'),
#  ('잠', 'NNG'),
#  ('을', 'JKO'),
#  ('많이', 'MAG'),
#  ('자', 'VV'),
#  ('ㄴ다', 'EFN'),
#  ('.', 'SF')]

# %% [markdown]
# Kkma를 활용하여 한글 단어 품사 분석. nltk와 달리 문장을 tokenize하지 않고 그대로 넣어도 동작한다.

# %%
kotags = kkma.pos(sentence)

# %%
enParser = nltk.RegexpParser('NP: {<DT>?<JJ>*<NN.*>*}')

# %% [markdown]
# 명사구 = 관사가 하나 오거나 오지 않거나, 형용사가 없거나 여러개 오거나, 명사구가 없거나 여러개 오거나.

# %%
tree = enParser.parse(entags)
tree.draw()

# %% [markdown]
# 정의한 parser를 이용한 영문 문장 분석 결과를 tree형태로 보여준다.

# %%
koParser = nltk.RegexpParser("""
    NP: {<N.*>*<N.*>*?}
    VP: {<M.*>*<V.*>*<E.*>*}
""")

# %% [markdown]
# Kkma가 아닌 다른 형태소 분석기 사용시 분석 결과로 나오는 품사 tag가 다를 수 있으므로 Parser를 따로 정의해줘야 한다.

# %%
tree = koParser.parse(kotags)
tree.draw()

# %%
koParser = nltk.RegexpParser("""
    NP: {<N.*>*<N.*>*?}
    OP: {<N.*>*<JKO>*}
    VP: {<M.*>*<V.*>*<E.*>*}
""")

# %%
tree = koParser.parse(kotags)
tree.draw()

# %% [markdown]
# 목적어구를 찾기 위해 Parser 수정.

# %%
for subtree in tree.subtrees():
    if subtree.label() == "NP":
        print(subtree, type(subtree))
        print(' '.join(e[0] for e in list(subtree)))
# Out:
# (NP 내/NP 친구/NNG) <class 'nltk.tree.Tree'>
# 내 친구
# (NP 잠/NNG) <class 'nltk.tree.Tree'>
# 잠

# %% [markdown]
# 명사구의 단어들만 가져왔다.

# %%
for subtree in tree.subtrees():
    if subtree.label() == "VP":
        print(subtree, type(subtree))
        print(' '.join(e[0] for e in list(subtree)))
# Out:
# (VP 많이/MAG 자/VV ㄴ다/EFN) <class 'nltk.tree.Tree'>
# 많이 자 ㄴ다

# %% [markdown]
# 동사구의 단어들만 가져왔다.

# %%
en.collocations()
# Out:
# Mrs Weston; Frank Churchill; Miss Woodhouse; Mrs Elton; Miss Bates;
# Jane Fairfax; Miss Fairfax; every thing; young man; every body; great
# deal; Mrs Goddard; dare say; Maple Grove; John Knightley; Miss Taylor;
# Miss Smith; Robert Martin; Colonel Campbell; Box Hill

# %%
ko.collocations()
# Out:
# 정치적 중립성; 재판소 재판관

# %% [markdown]
# 단어의 위치에 기반하여 해당 Text에서 자주 나온 단어 쌍을 찾을수 있다.

# %%
ko.collocations(window_size=3)
# Out:
# 정치적 중립성; 재판소 재판관; 대법원장 대법관; 대통령 국무총리; 그러하 아니하

# %% [markdown]
# 앞 뒤 3개의 단어를 기준으로 해당 Text에서 자주 나온 단어 쌍을 찾는다.

# %%
from nltk import collocations

# %%
measure = collocations.BigramAssocMeasures()

# %%
taggedWords = kkma.pos(corpus)

# %%
finder = collocations.BigramCollocationFinder.from_words(taggedWords)

for row in finder.nbest(measure.pmi, 5):
    print(row)
# Out:
# (('가부', 'NNG'), ('동수', 'NNG'))
# (('강제', 'NNG'), ('노역', 'NNG'))
# (('경자', 'NNG'), ('유전', 'NNG'))
# (('고', 'ECS'), ('채취', 'NNG'))
# (('공무', 'NNG'), ('담임', 'NNG'))

# %% [markdown]
# pmi를 적용하여 tokenize된 문장에서 collocation을 찾는다.(단어, 태그 쌍으로 들어감)
#
# pmi(x, y) = lg(p(x, y) / (p(x) * p(y)))

# %%
tags = [t for (w, t) in taggedWords]
tags
# Out:
# ['NNG',
#  'NNG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNM',
#  'VV',
#  'ETD',
#  'NNG',
#  'JX',
#  'NR',
#  'SP',
#  'NR',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NR',
#  'SP',
#  'NR',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'MAG',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'MAG',
#  'MAG',
#  'MAG',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'JKG',
#  'MDT',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'MAG',
#  'SP',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'VCP',
#  'ETD',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETN',
#  'JKM',
#  'NP',
#  'XSN',
#  'JKO',
#  'NP',
#  'XSN',
#  'JKG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'MAG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NR',
#  'NNM',
#  'NR',
#  'NNM',
#  'NR',
#  'NNM',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NR',
#  'NNM',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'MDT',
#  'NNG',
#  'NNG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'VCP',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'JX',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKC',
#  'VV',
#  'ETD',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JC',
#  'MDT',
#  'NNG',
#  'JX',
#  'MAG',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'VV',
#  'ETD',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECE',
#  'NNG',
#  'XSN',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETN',
#  'JKO',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECE',
#  'SP',
#  'MDT',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'MDT',
#  'NNG',
#  'JKS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ETD',
#  'NNG',
#  'VCP',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'VCP',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'MDT',
#  'NNG',
#  'SP',
#  'NNG',
#  'JKM',
#  'NNG',
#  'JKS',
#  'NNG',
#  'VCP',
#  'ECD',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECD',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNB',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKS',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'MDT',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'XSV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKG',
#  'NNG',
#  'SP',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'NNG',
#  'NR',
#  'NNM',
#  'MDT',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKM',
#  'JKG',
#  'NNG',
#  'JC',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECE',
#  'VV',
#  'ETD',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSA',
#  'EFN',
#  'SF',
#  'NP',
#  'JX',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'NNG',
#  'JKG',
#  'MDT',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JX',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NP',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNB',
#  'VA',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'NNB',
#  'JKG',
#  'NNG',
#  'JX',
#  'VV',
#  'ETD',
#  'VA',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'JKS',
#  'VV',
#  'ECE',
#  'SP',
#  'VA',
#  'ETD',
#  'NNG',
#  'JX',
#  'MAG',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'NP',
#  'JKG',
#  'NR',
#  'NR',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKO',
#  'VV',
#  'EFN',
#  'SF',
#  'NP',
#  'JX',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'NNG',
#  'SP',
#  'NNG',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNP',
#  'NNG',
#  'JX',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECD',
#  'VXV',
#  'ECE',
#  'SP',
#  'NNG',
#  'NNG',
#  'NP',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VXV',
#  'EFN',
#  'SF',
#  'SW',
#  'NNG',
#  'SP',
#  'NNG',
#  'SP',
#  'NNG',
#  'MAG',
#  'NNG',
#  'JKO',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'VV',
#  'ECS',
#  'NNG',
#  'JKS',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'NNG',
#  'XSV',
#  'ECD',
#  'VV',
#  'EFN',
#  'SF',
#  'MAG',
#  'SP',
#  'NNG',
#  'NNG',
#  'VCP',
#  'ETD',
#  'NNG',
#  'JC',
#  'NNG',
#  'NR',
#  'NNM',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKM',
#  'NNG',
#  'XSV',
#  'ETD',
#  'NNG',
#  'JKO',
#  'VV',
#  'ECE',
#  'NNG',
#  'MAG',
#  'NNG',
#  'NNG',
#  'JKG',
#  'NNG',
#  'JKS',
#  'VV',
#  'ETD',
#  'NNG',
#  'JKM',
#  'JX',
#  ...]

# %%
words = [w for (w, t) in taggedWords]
words
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '하',
#  'ㄴ',
#  '역사',
#  '와',
#  '전통',
#  '에',
#  '빛나',
#  '는',
#  '우리',
#  '대하',
#  'ㄴ',
#  '국민',
#  '은',
#  '3',
#  '·',
#  '1',
#  '운동',
#  '으로',
#  '건립',
#  '되',
#  'ㄴ',
#  '대한민국',
#  '임시',
#  '정부',
#  '의',
#  '법통',
#  '과',
#  '불의',
#  '에',
#  '항거',
#  '하',
#  'ㄴ',
#  '4',
#  '·',
#  '19',
#  '민주',
#  '이념',
#  '을',
#  '계승',
#  '하',
#  '고',
#  ',',
#  '조국',
#  '의',
#  '민주',
#  '개혁',
#  '과',
#  '평화적',
#  '통일',
#  '의',
#  '사명',
#  '에',
#  '입각',
#  '하',
#  '여',
#  '정의',
#  '·',
#  '인도',
#  '와',
#  '동포애',
#  '로써',
#  '민족',
#  '의',
#  '단결',
#  '을',
#  '공고히',
#  '하',
#  '고',
#  ',',
#  '모든',
#  '사회적',
#  '폐습',
#  '과',
#  '불의',
#  '를',
#  '타파',
#  '하',
#  '며',
#  ',',
#  '자율',
#  '과',
#  '조화',
#  '를',
#  '바탕',
#  '으로',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '를',
#  '더욱',
#  '확고히',
#  '하여',
#  '정치',
#  '·',
#  '경제',
#  '·',
#  '사회',
#  '·',
#  '문화',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '각인',
#  '의',
#  '기회',
#  '를',
#  '균등',
#  '히',
#  '하',
#  '고',
#  ',',
#  '능력',
#  '을',
#  '최고',
#  '도로',
#  '발휘',
#  '하',
#  '게',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '와',
#  '권리',
#  '에',
#  '따르',
#  '는',
#  '책임',
#  '과',
#  '의무',
#  '를',
#  '완수',
#  '하',
#  '게',
#  '하여',
#  ',',
#  '안',
#  '으로',
#  '는',
#  '국민',
#  '생활',
#  '의',
#  '균등',
#  '하',
#  'ㄴ',
#  '향상',
#  '을',
#  '기하',
#  '고',
#  '밖',
#  '으로',
#  '는',
#  '항구적',
#  '이',
#  'ㄴ',
#  '세계',
#  '평화',
#  '와',
#  '인류',
#  '공영',
#  '에',
#  '이바지',
#  '하',
#  'ㅁ',
#  '으로써',
#  '우리',
#  '들',
#  '과',
#  '우리',
#  '들',
#  '의',
#  '자손',
#  '의',
#  '안전',
#  '과',
#  '자유',
#  '와',
#  '행복',
#  '을',
#  '영원히',
#  '확보',
#  '하',
#  'ㄹ',
#  '것',
#  '을',
#  '다짐',
#  '하',
#  '면서',
#  '1948',
#  '년',
#  '7',
#  '월',
#  '12',
#  '일',
#  '에',
#  '제정',
#  '되',
#  '고',
#  '8',
#  '차',
#  '에',
#  '걸치',
#  '어',
#  '개정',
#  '되',
#  'ㄴ',
#  '헌법',
#  '을',
#  '이제',
#  '국회',
#  '의',
#  '의결',
#  '을',
#  '거치',
#  '어',
#  '국민',
#  '투표',
#  '에',
#  '의하',
#  '여',
#  '개정',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '1',
#  '장',
#  '총',
#  '강',
#  '제',
#  '1',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '민주',
#  '공화국',
#  '이',
#  '다',
#  '.',
#  '②',
#  '대한민국',
#  '의',
#  '주권',
#  '은',
#  '국민',
#  '에게',
#  '있',
#  '고',
#  ',',
#  '모든',
#  '권력',
#  '은',
#  '국민',
#  '으로',
#  '부터',
#  '나오',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '조',
#  '①',
#  '대한민국',
#  '의',
#  '국민',
#  '이',
#  '되',
#  '는',
#  '요건',
#  '은',
#  '법률',
#  '로',
#  '정하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '재외',
#  '국민',
#  '을',
#  '보호',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '3',
#  '조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도',
#  '서로',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '4',
#  '조',
#  '대한민국',
#  '은',
#  '통일',
#  '을',
#  '지향',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '입각',
#  '하',
#  'ㄴ',
#  '평화적',
#  '통일',
#  '정책',
#  '을',
#  '수립',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '추진',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '5',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '국제',
#  '평화',
#  '의',
#  '유지',
#  '에',
#  '노력',
#  '하',
#  '고',
#  '침략',
#  '적',
#  '전쟁',
#  '을',
#  '부인',
#  '하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국',
#  '군은',
#  '국가',
#  '의',
#  '안전',
#  '보장',
#  '과',
#  '국토',
#  '방위',
#  '의',
#  '신성',
#  '하',
#  'ㄴ',
#  '의무',
#  '를',
#  '수행',
#  '하',
#  'ㅁ',
#  '을',
#  '사명',
#  '으로',
#  '하',
#  '며',
#  ',',
#  '그',
#  '정치적',
#  '중립성',
#  '은',
#  '준수',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '6',
#  '조',
#  '①',
#  '헌법',
#  '에',
#  '의하',
#  '여',
#  '체결',
#  '·',
#  '공포',
#  '되',
#  'ㄴ',
#  '조약',
#  '과',
#  '일반적',
#  '으로',
#  '승인',
#  '되',
#  'ㄴ',
#  '국제',
#  '법규',
#  '는',
#  '국내',
#  '법과',
#  '같',
#  '은',
#  '효력',
#  '을',
#  '가지',
#  'ㄴ다',
#  '.',
#  '②',
#  '외국인',
#  '은',
#  '국제법',
#  '과',
#  '조약',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '그',
#  '지위',
#  '가',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '7',
#  '조',
#  '①',
#  '공무원',
#  '은',
#  '국민',
#  '전체',
#  '에',
#  '대하',
#  'ㄴ',
#  '봉사자',
#  '이',
#  '며',
#  ',',
#  '국민',
#  '에',
#  '대하',
#  '여',
#  '책임',
#  '을',
#  '질',
#  'ㄴ다',
#  '.',
#  '②',
#  '공무원',
#  '의',
#  '신분',
#  '과',
#  '정치적',
#  '중립성',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '8',
#  '조',
#  '①',
#  '정당',
#  '의',
#  '설립',
#  '은',
#  '자유',
#  '이',
#  '며',
#  ',',
#  '복수',
#  '정당제',
#  '는',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '②',
#  '정당',
#  '은',
#  '그',
#  '목적',
#  '·',
#  '조직',
#  '과',
#  '활동',
#  '이',
#  '민주적',
#  '이',
#  '어야',
#  '하',
#  '며',
#  ',',
#  '국민',
#  '의',
#  '정치적',
#  '의사',
#  '형성',
#  '에',
#  '참여',
#  '하',
#  '는데',
#  '필요',
#  '하',
#  'ㄴ',
#  '조직',
#  '을',
#  '가지',
#  '어야',
#  '하',
#  'ㄴ다',
#  '.',
#  '③',
#  '정당',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '국가',
#  '의',
#  '보호',
#  '를',
#  '받',
#  '으며',
#  ',',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '정당',
#  '운영',
#  '에',
#  '필요',
#  '하',
#  'ㄴ',
#  '자금',
#  '을',
#  '보조',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '다',
#  '.',
#  '④',
#  '정당',
#  '의',
#  '목적',
#  '이나',
#  '활동',
#  '이',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '위배',
#  '되',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '정부',
#  '는',
#  '헌법',
#  '재판소',
#  '에',
#  '그',
#  '해산',
#  '을',
#  '제소',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '고',
#  ',',
#  '정당',
#  '은',
#  '헌법',
#  '재판소',
#  '의',
#  '심판',
#  '에',
#  '의하',
#  '여',
#  '해산',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '9',
#  '조',
#  '국가',
#  '는',
#  '전통문화',
#  '의',
#  '계승',
#  '·',
#  '발전',
#  '과',
#  '민족',
#  '문화',
#  '의',
#  '창달',
#  '에',
#  '노력',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '장',
#  '국민',
#  '의',
#  '권리',
#  '와',
#  '의무',
#  '제',
#  '10',
#  '조',
#  '모든',
#  '국민',
#  '은',
#  '인간',
#  '으로서',
#  '의',
#  '존엄',
#  '과',
#  '가치',
#  '를',
#  '가지',
#  '며',
#  ',',
#  '행복',
#  '을',
#  '추구',
#  '하',
#  'ㄹ',
#  '권리',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '국가',
#  '는',
#  '개인',
#  '이',
#  '가지',
#  '는',
#  '불가침',
#  '의',
#  '기본적',
#  '인권',
#  '을',
#  '확인',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '보장',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '11',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '법',
#  '앞',
#  '에',
#  '평등',
#  '하',
#  '다',
#  '.',
#  '누구',
#  '든지',
#  '성별',
#  '·',
#  '종교',
#  '또는',
#  '사회적',
#  '신분',
#  '에',
#  '의하',
#  '여',
#  '정치적',
#  '·',
#  '경제적',
#  '·',
#  '사회적',
#  '·',
#  '문화적',
#  '생활',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '차별',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '사회적',
#  '특수',
#  '계급',
#  '의',
#  '제도',
#  '는',
#  '인정',
#  '되',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '형태',
#  '로',
#  '도',
#  '이',
#  '를',
#  '창설',
#  '하',
#  'ㄹ',
#  '수',
#  '없',
#  '다',
#  '.',
#  '③',
#  '훈장',
#  '등',
#  '의',
#  '영전',
#  '은',
#  '이르',
#  'ㄹ',
#  '받',
#  '은',
#  '자',
#  '에게',
#  '만',
#  '효력',
#  '이',
#  '있',
#  '고',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '특권',
#  '도',
#  '이에',
#  '따르',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '12',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '신체',
#  '의',
#  '자유',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '누구',
#  '든지',
#  '법률',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '·',
#  '수색',
#  '또는',
#  '심문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '법률',
#  '과',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '처벌',
#  '·',
#  '보안',
#  '처분',
#  '또는',
#  '강제',
#  '노역',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '모든',
#  '국민',
#  '은',
#  '고문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '형',
#  '사상',
#  '자기',
#  '에게',
#  '불리',
#  '하',
#  'ㄴ',
#  '진술',
#  '을',
#  '강요',
#  '당하',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '③',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '또는',
#  '수색',
#  '을',
#  '하',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '따르',
#  '아',
#  '검사',
#  '의',
#  '신청',
#  '에',
#  '의하',
#  '여',
#  '법관',
#  '이',
#  '발부',
#  '하',
#  'ㄴ',
#  '영장',
#  '을',
#  '제시',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '다만',
#  ',',
#  '현행',
#  '범인',
#  '이',
#  'ㄴ',
#  '경우',
#  '와',
#  '장기',
#  '3',
#  '년',
#  '이상',
#  '의',
#  '형',
#  '에',
#  '해당',
#  '하',
#  '는',
#  '죄',
#  '를',
#  '범하',
#  '고',
#  '도피',
#  '또는',
#  '증거',
#  '인멸',
#  '의',
#  '염려',
#  '가',
#  '있',
#  '을',
#  '때',
#  '에',
#  '는',
#  ...]

# %%
finder = collocations.BigramCollocationFinder.from_words(tags)

for row in finder.nbest(measure.pmi, 5):
    print(row)
# Out:
# ('XR', 'XSA')
# ('JKC', 'VCN')
# ('EPT', 'EPT')
# ('VCN', 'ECD')
# ('ECD', 'VX')

# %% [markdown]
# tag를 대상으로 collocation을 찾음으로써 어떤 tag끼리 주로 붙어서 나오는지 알 수 있다.

# %%
finder = collocations.BigramCollocationFinder.from_words(words)

for row in finder.nbest(measure.pmi, 5):
    print(row)
# Out:
# ('가부', '동수')
# ('강제', '노역')
# ('경자', '유전')
# ('공무', '담임')
# ('공중', '도덕')

# %% [markdown]
# word를 대상으로 collocation을 찾음으로써 어떤 word끼리 주로 붙어서 나오는지 알 수 있다.

# %%
ko.vocab()
# Out:
# FreqDist({'의': 532, '하': 457, '.': 359, '에': 328, '는': 281, 'ㄴ다': 243, 'ㄴ': 234, '을': 232, '은': 195, '이': 192, ...})

# %% [markdown]
# corpus내 단어 등장 횟수를 나열하여 dict로 만들어준다.

# %% [markdown]
# ___

# %% [markdown]
# ## Making Wordcloud

# %%
for k, v in ko.vocab().items():
    print(k, v)
# Out:
# 대한민국 11
# 헌법 69
# 유구 1
# 하 457
# ㄴ 234
# 역사 1
# 와 42
# 전통 1
# 에 328
# 빛나 1
# 는 281
# 우리 3
# 대하 19
# 국민 69
# 은 195
# 3 24
# · 145
# 1 28
# 운동 3
# 으로 57
# 건립 1
# 되 113
# 임시 3
# 정부 23
# 의 532
# 법통 1
# 과 82
# 불의 2
# 항거 1
# 4 14
# 19 2
# 민주 6
# 이념 1
# 을 232
# 계승 2
# 고 39
# , 101
# 조국 3
# 개혁 1
# 평화적 4
# 통일 9
# 사명 2
# 입각 2
# 여 149
# 정의 2
# 인도 1
# 동포애 1
# 로써 5
# 민족 3
# 단결 1
# 공고히 1
# 모든 37
# 사회적 5
# 폐습 1
# 를 135
# 타파 1
# 며 45
# 자율 2
# 조화 2
# 바탕 1
# 자유 21
# 민주적 4
# 기본 8
# 질서 8
# 더욱 1
# 확고히 1
# 하여 3
# 정치 4
# 경제 18
# 사회 4
# 문화 3
# 영역 4
# 있 99
# 어서 9
# 각인 1
# 기회 4
# 균등 4
# 히 1
# 능력 3
# 최고 3
# 도로 1
# 발휘 1
# 게 6
# 권리 21
# 따르 7
# 책임 5
# 의무 20
# 완수 1
# 안 15
# 생활 8
# 향상 4
# 기하 1
# 밖 1
# 항구적 1
# 이 192
# 세계 1
# 평화 5
# 인류 1
# 공영 1
# 이바지 1
# ㅁ 6
# 으로써 4
# 들 2
# 자손 1
# 안전 11
# 행복 2
# 영원히 1
# 확보 1
# ㄹ 141
# 것 7
# 다짐 1
# 면서 1
# 1948 1
# 년 12
# 7 4
# 월 3
# 12 3
# 일 19
# 제정 8
# 8 4
# 차 3
# 걸치 1
# 어 13
# 개정 9
# 이제 1
# 국회 55
# 의결 16
# 거치 2
# 투표 8
# 의하 83
# ㄴ다 243
# . 359
# 저 155
# 장 15
# 총 1
# 강 1
# 제 20
# 조 136
# ① 78
# 공화국 1
# 다 88
# ② 78
# 주권 2
# 에게 10
# 권력 1
# 부터 13
# 나오 1
# 2 19
# 요건 1
# 법률 121
# 로 62
# 정하 88
# 국가 73
# 바 37
# 재외 1
# 보호 15
# 질 13
# 영토 2
# 한반도 1
# 그 46
# 부속 1
# 도 8
# 서로 1
# 지향 2
# 정책 14
# 수립 7
# 이르 14
# 추진 1
# 5 10
# 국제 3
# 유지 7
# 노력 13
# 침략 1
# 적 2
# 전쟁 1
# 부인 1
# 국 21
# 군은 1
# 보장 24
# 국토 3
# 방위 2
# 신성 1
# 수행 4
# 정치적 5
# 중립성 3
# 준수 2
# 6 10
# 체결 4
# 공포 11
# 조약 11
# 일반적 1
# 승인 6
# 법규 1
# 국내 2
# 법과 1
# 같 4
# 효력 9
# 가지 32
# 외국인 1
# 국제법 1
# 지위 3
# 가 45
# 공무원 17
# 전체 1
# 봉사자 1
# 신분 3
# 정당 14
# 설립 1
# 복수 1
# 정당제 1
# 목적 4
# 조직 18
# 활동 3
# 어야 21
# 의사 2
# 형성 1
# 참여 1
# 는데 1
# 필요 31
# ③ 45
# 받 41
# 으며 6
# 운영 5
# 자금 1
# 보조 1
# 수 88
# ④ 20
# 이나 10
# 위배 3
# 때 55
# 재판소 14
# 해산 5
# 제소 3
# 심판 12
# 9 4
# 전통문화 1
# 발전 5
# 창달 2
# 여야 31
# 10 5
# 인간 3
# 으로서 5
# 존엄 2
# 가치 1
# 추구 1
# 개인 3
# 불가침 1
# 기본적 1
# 인권 1
# 확인 1
# 11 3
# 법 6
# 앞 2
# 평등 4
# 누구 6
# 든지 6
# 성별 1
# 종교 3
# 또는 69
# 경제적 2
# 문화적 1
# 차별 2
# 지 57
# 아니하 53
# 특수 1
# 계급 1
# 제도 5
# 인정 8
# 어떠하 2
# 형태 1
# 창설 1
# 없 30
# 훈장 2
# 등 6
# 영전 3
# 자 10
# 만 1
# 특권 1
# 이에 5
# 신체 3
# 고는 12
# 체포 9
# 구속 8
# 압수 3
# 수색 3
# 심문 1
# 적법 2
# 절차 9
# 처벌 3
# 보안 1
# 처분 12
# 강제 1
# 노역 1
# 고문 2
# 형 4
# 사상 6
# 자기 2
# 불리 3
# 진술 5
# 강요 1
# 당하 9
# 아 7
# 검사 4
# 신청 2
# 법관 11
# 발부 2
# 영장 4
# 제시 2
# 다만 11
# 현행 3
# 범인 3
# 경우 17
# 장기 1
# 이상 18
# 해당 1
# 죄 4
# 범하 2
# 도피 1
# 증거 3
# 인멸 1
# 염려 2
# 사후 1
# 청구 6
# 즉시 2
# 변호인 4
# 조력 2
# 형사 6
# 피고인 6
# 스스로 1
# 구하 1
# 붙이 5
# ⑤ 11
# 이유 7
# 있음 1
# 고지 1
# 자의 2
# 가족 2
# 일시 1
# 장소 1
# 지체 6
# 없이 8
# 통지 1
# ⑥ 6
# 적부 1
# 심사 5
# 법원 17
# ⑦ 3
# 자백 2
# 폭행 1
# 협박 1
# 부당 2
# 장기화 1
# 기망 1
# 기타 26
# 방법 4
# 아니 11
# 라고 1
# 정식 1
# 재판 15
# 유일 1
# 유죄 2
# 삼 1
# 거나 20
# 13 2
# 행위시 1
# 범죄 4
# 구성 8
# 행위 8
# 소 1
# 추 1
# 동일 1
# 거듭 1
# 소급 1
# 입법 2
# 참정권 1
# 제한 7
# 재산권 4
# 박탈 1
# 친족 1
# 인하 6
# 불 2
# 이익 5
# 처우 2
# 14 2
# 거주 1
# 이전 2
# 15 4
# 직업 1
# 선택 1
# 16 2
# 주거 3
# 침해 6
# 나 12
# 17 2
# 사생활 1
# 비밀 4
# 18 1
# 통신 2
# 양심 3
# 20 3
# 국교 1
# 분리 1
# 21 1
# 언론 5
# 출판 5
# 집회 12
# 결사 3
# 허 1
# 검열 1
# 허가 1
# 방송 1
# 시설 2
# 기준 2
# 신문 1
# 기능 1
# 기 16
# 위하 33
# 사항 23
# 타인 4
# 명예 2
# 공중 1
# 도덕 1
# 윤리 1
# 여서 1
# 알 1
# 니 1
# 피해자 2
# 대 1
# 피해 2
# 배상 3
# 22 1
# 학문 1
# 예술 1
# 저작자 1
# 발명가 1
# 과학 2
# 기술자 1
# 예술가 1
# 23 1
# 내용 5
# 한계 1
# 행사 3
# 공공 8
# 복리 4
# 적합 1
# 도록 4
# 수용 1
# 사용 1
# 및 25
# 보상 4
# 정 5
# 지급 1
# 24 1
# 선거권 4
# 25 2
# 공무 1
# 담임 1
# 권 1
# 26 1
# 기관 10
# 문서 3
# 청원 3
# 27 1
# 군인 5
# 군무원 3
# 에서 24
# 중대 5
# 군 3
# 기밀 1
# 초병 2
# 초소 2
# 유독 2
# 음식물 2
# 공급 2
# 포로 2
# 군용물 1
# 관하 53
# 중 10
# 비상계엄 2
# 선포 4
# 제외 5
# 군사 10
# 신속 1
# 상당 1
# 한 6
# 공개 7
# 판결 4
# 확정 8
# 까 1
# 무죄 2
# 추정 1
# 당해 1
# 사건 1
# 28 1
# 피의자 1
# 구금 3
# 었 2
# 더 2
# 자가 3
# 불기소 1
# 29 2
# 직무 19
# 상 8
# 불법 2
# 손해 2
# 단체 16
# 자신 1
# 면제 2
# 경찰 1
# 전투 1
# 훈련 1
# 집행 4
# 관련 2
# 외 2
# 30 5
# 생명 1
# 구조 2
# 31 1
# 교육 10
# 자녀 1
# 적어도 1
# 초등 1
# 무상 1
# 자주성 1
# 전문 1
# 성 1
# 대학 1
# 자율성 1
# 평생 2
# 진흥 1
# 학교 2
# 포함 2
# 재정 5
# 교원 1
# 적인 2
# 32 1
# 근로 9
# 근로자 4
# 고용 2
# 증진 3
# 적정 2
# 임금 2
# 최저 1
# 임금제 1
# 시행 12
# 조건 4
# 주의 1
# 원칙 2
# 존엄성 1
# 여자 2
# 특별 6
# 연소자 1
# 유공자 1
# 상이 1
# 군경 2
# 전몰 1
# 유가족 1
# 우선적 1
# 부여받 1
# 33 1
# 자주적 1
# 단결권 2
# 교섭권 2
# 행동권 3
# 한하 7
# 주요 1
# 산업체 1
# 종사 1
# 34 1
# 답 1
# 복지 2
# 권익 1
# 노인과 1
# 청소년 1
# 복 1
# 실시 3
# 장애자 1
# 질병 1
# 노령 1
# 사유 3
# 재해 1
# 예방 1
# 위험 1
# 35 1
# 건강 1
# 쾌적 2
# 환경 2
# 보전 3
# 환경권 1
# 주택 1
# 개발 6
# 통하 3
# 36 1
# 혼인 1
# 양성 1
# 기초 1
# 성립 1
# 모성 1
# 보건 1
# 37 1
# 열거 1
# 경시 1
# 본질적 1
# 38 1
# 납세 1
# 39 1
# 국방 2
# 병역 1
# 이행 2
# 40 4
# 입법권 1
# 속하 5
# 41 1
# 보통 2
# 직접 2
# 선거 26
# 선출 7
# 국회의원 18
# 200 1
# 인 9
# 선거구 1
# 비례 1
# 대표제 1
# 42 1
# 임기 18
# 43 1
# 직 2
# 겸하 2
# 44 1
# 회기 6
# 동의 9
# 전 6
# 요구 13
# 으면 1
# 석방 1
# 45 1
# 행 1
# 발언 2
# 표결 1
# 지지 1
# 46 1
# 청렴 1
# 우선 1
# 행하 4
# 남용 2
# 기업체 2
# 계약 3
# 재 1
# 산상 1
# 직위 1
# 취득 2
# 알선 1
# 47 1
# 회의 42
# 매년 2
# 회 1
# 임시회 2
# 대통령 84
# 재적 14
# 의원 23
# 분 8
# 정기 1
# 100 2
# 초과 1
# 기간 5
# 명시 1
# 48 1
# 의장 6
# 인과 2
# 부의장 1
# 49 1
# 규정 6
# 과반수 10
# 출석 12
# 찬성 12
# 가부 1
# 동수 1
# 부결 1
# 보 6
# 50 1
# 하다 2
# 공표 1
# 51 1
# 제출 8
# 법률안 7
# 의안 1
# 못하 4
# 폐기 1
# 만료 3
# 그러하 2
# 52 1
# 53 1
# 이송 2
# 이내 6
# 이의 2
# 항 22
# 내 2
# 서 1
# 환부 1
# 재의 5
# 폐회 1
# 또한 2
# 일부 1
# 또 1
# 수정 1
# 반 1
# 수의 1
# 전과 1
# 면 8
# 로서 3
# 후 6
# 날 2
# 경과 1
# 발생 2
# 54 1
# 예산안 5
# 심의 5
# 회계 6
# 연도 5
# 마다 1
# 편성 3
# 개시 5
# 90 2
# 까지 10
# 새 2
# 롭 1
# 예산 5
# 안이 1
# 다음 4
# 경비 3
# 전년도 1
# 준하 2
# 설치 5
# 지출 4
# 이미 1
# 사업 1
# 계속 3
# 55 1
# 넘 1
# 연한 1
# 비로서 1
# 얻 18
# 예비비 2
# 총액 1
# 차기 1
# 56 1
# 변경 3
# 가하 1
# 추가 1
# 경정 1
# 57 1
# 각 4
# 항의 1
# 금액 1
# 증가 1
# 비목 1
# 58 1
# 국채 1
# 모집 1
# 예산외 1
# 부담 4
# 려 1
# 미리 1
# 59 1
# 조세 1
# 종목 1
# 세율 1
# 60 3
# 상호 3
# 원조 1
# 중요 10
# 우호 1
# 통상 1
# 항해 1
# 제약 1
# 강화 3
# 재정적 1
# 지우 1
# 비준 2
# 동의권 2
# 선전 3
# 포고 2
# 국군 2
# 외국 3
# 파견 2
# 군대 1
# 주류 1
# 61 1
# 국정 7
# 감사 7
# 특정 1
# 사안 1
# 조사 2
# 서류 1
# 증인 1
# 증언 1
# 의견 3
# 62 1
# 국무 30
# 총리 6
# 위원 31
# 위원회 7
# 처리 6
# 상황 2
# 질문 1
# 응답 1
# 국무총리 13
# 답변 2
# 하여금 1
# 63 1
# 해임 3
# 건의 3
# 발의 4
# 64 1
# 저촉 4
# 범위 16
# 내부 4
# 규율 4
# 규칙 6
# 자격 6
# 징계 2
# 제명 1
# 려면 2
# 65 1
# 행정 15
# 각부 9
# 재판관 8
# 중앙 3
# 관리 13
# 감사원장 2
# 탄핵 11
# 소추 5
# 결 1
# 권한 11
# 정지 1
# 결정 6
# 공직 1
# 파면 1
# 그치 1
# 그러 1
# 민 1
# 절 3
# 66 1
# 원수 1
# 대표 1
# 독립 2
# 계속성 1
# 수호 1
# 책무 1
# 성실 1
# 행정권 1
# 수반 1
# 67 1
# 득표자 1
# 과반 1
# 수가 1
# 다수 1
# 표 1
# 당선 2
# 자로 1
# 후보자 2
# 득표수 1
# 총수 1
# 피 1
# 선거일 1
# 현재 1
# 세 1
# 달하 1
# 68 1
# 70 2
# 내지 1
# 후임자 4
# 궐 2
# 위 4
# 당선자 1
# 사망 1
# 상실 2
# 69 1
# 취임 1
# 즈음 1
# 선서 2
# " 2
# 보위 2
# 직책 1
# 성실히 1
# 엄숙히 1
# ㅂ니다 1
# 중임 6
# 71 1
# 사고 1
# 정한 1
# 순서 1
# 대행 1
# 72 1
# 외교 2
# 73 1
# 사절 1
# 신임 1
# 접수 1
# 74 1
# 통수 1
# 군의 1
# 75 1
# 구체적 1
# 위임 3
# 대통령령 3
# 발하 4
# 76 1
# 내우 1
# 외환 2
# 천재 1
# 지변 1
# 상의 4
# 위기 1
# 안녕 3
# 긴급 4
# 조치 3
# 기다리 1
# 여유 1
# 최소한 1
# 관 5
# 명령 9
# 안위 1
# 관계 4
# 교전 1
# 상태 1
# 불가능 1
# 그때 1
# 폐지 1
# 당연히 1
# 회복 1
# 77 1
# 전시 1
# 사변 1
# 비상사태 1
# 병력 1
# 응하 6
# 계엄 8
# 비상 2
# 통고 1
# 해제 3
# 78 1
# 임면 1
# 79 1
# 사면 3
# 감형 3
# 복권 3
# 명하 2
# 일반 2
# 사 1
# 80 1
# 수여 2
# 81 1
# 서한 1
# 표시 1
# 82 1
# 국법 1
# 부서 1
# 83 1
# 공사 1
# 84 1
# 내란 1
# 재직 1
# 85 1
# 전직 1
# 예우 1
# 행정부 1
# 86 1
# 임명 19
# 보좌 2
# 명 1
# 통할 1
# 현역 2
# 면하 2
# 87 1
# 제청 6
# 구성원 1
# 88 1
# 이하 2
# 부의 1
# 장이 1
# 89 1
# 계획 5
# 대외 3
# 개정안 5
# 조약안 1
# 결산 3
# 국유 2
# 재산 2
# 간의 2
# 획정 1
# 정부안 1
# 배정 1
# 평가 1
# 분석 1
# 조정 3
# 회부 1
# 검찰 1
# 총장 3
# 합동 1
# 참모 2
# 국립대 1
# 대사 1
# 영기 1
# 업체 1
# 관리자 1
# 자문 12
# 원로 4
# 두 12
# 직전 2
# 지명 3
# 91 1
# 앞서 1
# 주재 1
# 92 1
# 93 1
# 94 1
# 95 1
# 소관 1
# 사무 8
# 직권 1
# 총리령 1
# 부령 1
# 96 1
# 감사원 5
# 97 1
# 세입 2
# 세출 2
# 감찰 1
# 소속하 1
# 98 1
# 원장 3
# 99 1
# 차년 1
# 결과 1
# 대상 1
# 101 1
# 사법권 1
# 원인 1
# 대법원 9
# 각급 3
# 관의 2
# 102 1
# 부 1
# 대법관 7
# 103 1
# 104 1
# 대법원장 9
# 105 1
# 장의 2
# 연임 3
# 정년 1
# 106 1
# 관은 1
# 금고 3
# 형의 3
# 선고 4
# 파 3
# 정직 1
# 감봉 1
# 관이 1
# 심신 1
# 장해 1
# 퇴직 1
# 107 1
# 위반 2
# 여부 3
# 전제 2
# 최종적 1
# 전심 1
# 사법 1
# 준용 1
# 108 1
# 소송 1
# 109 1
# 심리 2
# 방해 1
# 선량 1
# 풍속 1
# 해하 1
# 110 1
# 관할 2
# 상고심 1
# 하의 1
# 간첩죄 1
# 단심 1
# 사형 1
# 111 1
# 관장 1
# 위헌 2
# 간 4
# 지방 9
# 자치 9
# 쟁의 1
# 소원 2
# 인의 2
# 관중 2
# 인은 2
# 112 1
# 가입 2
# 관여 2
# 113 1
# 인용 1
# 114 1
# 공정 1
# 위원장 1
# 호선 1
# 원의 1
# 법령 3
# 급 2
# 115 1
# 선거인 1
# 명부 1
# 작성 1
# 지시 2
# 당 1
# 116 1
# 관리하 1
# 시키 1
# 117 1
# 주민 1
# 종류 1
# 118 1
# 의회 2
# 선임 4
# 119 1
# 기업 2
# 창의 1
# 존중 1
# 균형 5
# 성장 1
# 안정 2
# 소득 1
# 분배 1
# 시장 1
# 지배 1
# 경제력 1
# 방지 1
# 주체 1
# 민주화 1
# 규제 2
# 120 1
# 광물 1
# 지하 1
# 자원 3
# 수산 1
# 수력 1
# 이용 5
# 자연력 1
# 일정 1
# 채취 1
# 특허 1
# 121 1
# 농지 4
# 경자 1
# 유전 1
# 달성 2
# 소작 1
# 금지 1
# 농업 2
# 생산성 1
# 제고 1
# 합리 1
# 불가피 1
# 사정 1
# 임대차 1
# 위탁 1
# 경영 2
# 122 1
# 모두 1
# 생산 1
# 기반 1
# 효율적 1
# 과하 1
# 123 1
# 어업 1
# 육성 5
# 농 3
# 어촌 1
# 종합 1
# 지원 1
# 지역 2
# 중소기업 2
# 농수산물 1
# 수급 1
# 유통 1
# 개선 1
# 가격 1
# 도모 1
# 어민 2
# 자조 1
# 124 1
# 건전 1
# 소비 1
# 계도 1
# 생산품 1
# 품질 1
# 촉구 1
# 소비자 1
# 125 1
# 무역 1
# 126 1
# 국방상 1
# 길 1
# 사영 1
# 공유 1
# 통제 1
# 127 1
# 기술 1
# 혁신 1
# 정보 1
# 인력 1
# 표준 1
# 확립 1
# 기구 1
# 128 1
# 제안 3
# 연장 1
# 당시 6
# 129 1
# 공고 2
# 130 1
# 투표자 1
# 펴 1
# 침 1
# 부칙 2
# < 1
# 호 1
# 1987.10 1
# > 1
# 보기 1
# 1988 1
# 준비 1
# 최초 7
# 일로 3
# 전일 2
# 임원 1
# 임명권 1
# 전임자 1
# 판사 1
# 단서 1
# 불구하 1
# 적용 1
# 지속 1
# 새로 1
# 새롭 1
# 존속 1

# %%
with open('cloud.csv', 'w') as fp:
    fp.write('word, freq\n')
    
    for k, v in ko.vocab().items():
        fp.write('{0}, {1}\n'.format(k, v))
        
wordList = [k for (k, v) in kkma.pos(corpus)]

# %% [markdown]
# 형태소 분석 결과에서 단어만 가져와 리스트를 만들었다.

# %%
wordList
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '하',
#  'ㄴ',
#  '역사',
#  '와',
#  '전통',
#  '에',
#  '빛나',
#  '는',
#  '우리',
#  '대하',
#  'ㄴ',
#  '국민',
#  '은',
#  '3',
#  '·',
#  '1',
#  '운동',
#  '으로',
#  '건립',
#  '되',
#  'ㄴ',
#  '대한민국',
#  '임시',
#  '정부',
#  '의',
#  '법통',
#  '과',
#  '불의',
#  '에',
#  '항거',
#  '하',
#  'ㄴ',
#  '4',
#  '·',
#  '19',
#  '민주',
#  '이념',
#  '을',
#  '계승',
#  '하',
#  '고',
#  ',',
#  '조국',
#  '의',
#  '민주',
#  '개혁',
#  '과',
#  '평화적',
#  '통일',
#  '의',
#  '사명',
#  '에',
#  '입각',
#  '하',
#  '여',
#  '정의',
#  '·',
#  '인도',
#  '와',
#  '동포애',
#  '로써',
#  '민족',
#  '의',
#  '단결',
#  '을',
#  '공고히',
#  '하',
#  '고',
#  ',',
#  '모든',
#  '사회적',
#  '폐습',
#  '과',
#  '불의',
#  '를',
#  '타파',
#  '하',
#  '며',
#  ',',
#  '자율',
#  '과',
#  '조화',
#  '를',
#  '바탕',
#  '으로',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '를',
#  '더욱',
#  '확고히',
#  '하여',
#  '정치',
#  '·',
#  '경제',
#  '·',
#  '사회',
#  '·',
#  '문화',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '각인',
#  '의',
#  '기회',
#  '를',
#  '균등',
#  '히',
#  '하',
#  '고',
#  ',',
#  '능력',
#  '을',
#  '최고',
#  '도로',
#  '발휘',
#  '하',
#  '게',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '와',
#  '권리',
#  '에',
#  '따르',
#  '는',
#  '책임',
#  '과',
#  '의무',
#  '를',
#  '완수',
#  '하',
#  '게',
#  '하여',
#  ',',
#  '안',
#  '으로',
#  '는',
#  '국민',
#  '생활',
#  '의',
#  '균등',
#  '하',
#  'ㄴ',
#  '향상',
#  '을',
#  '기하',
#  '고',
#  '밖',
#  '으로',
#  '는',
#  '항구적',
#  '이',
#  'ㄴ',
#  '세계',
#  '평화',
#  '와',
#  '인류',
#  '공영',
#  '에',
#  '이바지',
#  '하',
#  'ㅁ',
#  '으로써',
#  '우리',
#  '들',
#  '과',
#  '우리',
#  '들',
#  '의',
#  '자손',
#  '의',
#  '안전',
#  '과',
#  '자유',
#  '와',
#  '행복',
#  '을',
#  '영원히',
#  '확보',
#  '하',
#  'ㄹ',
#  '것',
#  '을',
#  '다짐',
#  '하',
#  '면서',
#  '1948',
#  '년',
#  '7',
#  '월',
#  '12',
#  '일',
#  '에',
#  '제정',
#  '되',
#  '고',
#  '8',
#  '차',
#  '에',
#  '걸치',
#  '어',
#  '개정',
#  '되',
#  'ㄴ',
#  '헌법',
#  '을',
#  '이제',
#  '국회',
#  '의',
#  '의결',
#  '을',
#  '거치',
#  '어',
#  '국민',
#  '투표',
#  '에',
#  '의하',
#  '여',
#  '개정',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '1',
#  '장',
#  '총',
#  '강',
#  '제',
#  '1',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '민주',
#  '공화국',
#  '이',
#  '다',
#  '.',
#  '②',
#  '대한민국',
#  '의',
#  '주권',
#  '은',
#  '국민',
#  '에게',
#  '있',
#  '고',
#  ',',
#  '모든',
#  '권력',
#  '은',
#  '국민',
#  '으로',
#  '부터',
#  '나오',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '조',
#  '①',
#  '대한민국',
#  '의',
#  '국민',
#  '이',
#  '되',
#  '는',
#  '요건',
#  '은',
#  '법률',
#  '로',
#  '정하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '재외',
#  '국민',
#  '을',
#  '보호',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '3',
#  '조',
#  '대한민국',
#  '의',
#  '영토',
#  '는',
#  '한반도',
#  '와',
#  '그',
#  '부속',
#  '도',
#  '서로',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '4',
#  '조',
#  '대한민국',
#  '은',
#  '통일',
#  '을',
#  '지향',
#  '하',
#  '며',
#  ',',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '입각',
#  '하',
#  'ㄴ',
#  '평화적',
#  '통일',
#  '정책',
#  '을',
#  '수립',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '추진',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '5',
#  '조',
#  '①',
#  '대한민국',
#  '은',
#  '국제',
#  '평화',
#  '의',
#  '유지',
#  '에',
#  '노력',
#  '하',
#  '고',
#  '침략',
#  '적',
#  '전쟁',
#  '을',
#  '부인',
#  '하',
#  'ㄴ다',
#  '.',
#  '②',
#  '국',
#  '군은',
#  '국가',
#  '의',
#  '안전',
#  '보장',
#  '과',
#  '국토',
#  '방위',
#  '의',
#  '신성',
#  '하',
#  'ㄴ',
#  '의무',
#  '를',
#  '수행',
#  '하',
#  'ㅁ',
#  '을',
#  '사명',
#  '으로',
#  '하',
#  '며',
#  ',',
#  '그',
#  '정치적',
#  '중립성',
#  '은',
#  '준수',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '6',
#  '조',
#  '①',
#  '헌법',
#  '에',
#  '의하',
#  '여',
#  '체결',
#  '·',
#  '공포',
#  '되',
#  'ㄴ',
#  '조약',
#  '과',
#  '일반적',
#  '으로',
#  '승인',
#  '되',
#  'ㄴ',
#  '국제',
#  '법규',
#  '는',
#  '국내',
#  '법과',
#  '같',
#  '은',
#  '효력',
#  '을',
#  '가지',
#  'ㄴ다',
#  '.',
#  '②',
#  '외국인',
#  '은',
#  '국제법',
#  '과',
#  '조약',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '그',
#  '지위',
#  '가',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '7',
#  '조',
#  '①',
#  '공무원',
#  '은',
#  '국민',
#  '전체',
#  '에',
#  '대하',
#  'ㄴ',
#  '봉사자',
#  '이',
#  '며',
#  ',',
#  '국민',
#  '에',
#  '대하',
#  '여',
#  '책임',
#  '을',
#  '질',
#  'ㄴ다',
#  '.',
#  '②',
#  '공무원',
#  '의',
#  '신분',
#  '과',
#  '정치적',
#  '중립성',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '8',
#  '조',
#  '①',
#  '정당',
#  '의',
#  '설립',
#  '은',
#  '자유',
#  '이',
#  '며',
#  ',',
#  '복수',
#  '정당제',
#  '는',
#  '보장',
#  '되',
#  'ㄴ다',
#  '.',
#  '②',
#  '정당',
#  '은',
#  '그',
#  '목적',
#  '·',
#  '조직',
#  '과',
#  '활동',
#  '이',
#  '민주적',
#  '이',
#  '어야',
#  '하',
#  '며',
#  ',',
#  '국민',
#  '의',
#  '정치적',
#  '의사',
#  '형성',
#  '에',
#  '참여',
#  '하',
#  '는데',
#  '필요',
#  '하',
#  'ㄴ',
#  '조직',
#  '을',
#  '가지',
#  '어야',
#  '하',
#  'ㄴ다',
#  '.',
#  '③',
#  '정당',
#  '은',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '국가',
#  '의',
#  '보호',
#  '를',
#  '받',
#  '으며',
#  ',',
#  '국가',
#  '는',
#  '법률',
#  '이',
#  '정하',
#  '는',
#  '바',
#  '에',
#  '의하',
#  '여',
#  '정당',
#  '운영',
#  '에',
#  '필요',
#  '하',
#  'ㄴ',
#  '자금',
#  '을',
#  '보조',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '다',
#  '.',
#  '④',
#  '정당',
#  '의',
#  '목적',
#  '이나',
#  '활동',
#  '이',
#  '민주적',
#  '기본',
#  '질서',
#  '에',
#  '위배',
#  '되',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '정부',
#  '는',
#  '헌법',
#  '재판소',
#  '에',
#  '그',
#  '해산',
#  '을',
#  '제소',
#  '하',
#  'ㄹ',
#  '수',
#  '있',
#  '고',
#  ',',
#  '정당',
#  '은',
#  '헌법',
#  '재판소',
#  '의',
#  '심판',
#  '에',
#  '의하',
#  '여',
#  '해산',
#  '되',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '9',
#  '조',
#  '국가',
#  '는',
#  '전통문화',
#  '의',
#  '계승',
#  '·',
#  '발전',
#  '과',
#  '민족',
#  '문화',
#  '의',
#  '창달',
#  '에',
#  '노력',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '2',
#  '장',
#  '국민',
#  '의',
#  '권리',
#  '와',
#  '의무',
#  '제',
#  '10',
#  '조',
#  '모든',
#  '국민',
#  '은',
#  '인간',
#  '으로서',
#  '의',
#  '존엄',
#  '과',
#  '가치',
#  '를',
#  '가지',
#  '며',
#  ',',
#  '행복',
#  '을',
#  '추구',
#  '하',
#  'ㄹ',
#  '권리',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '국가',
#  '는',
#  '개인',
#  '이',
#  '가지',
#  '는',
#  '불가침',
#  '의',
#  '기본적',
#  '인권',
#  '을',
#  '확인',
#  '하',
#  '고',
#  '이르',
#  'ㄹ',
#  '보장',
#  '하',
#  'ㄹ',
#  '의무',
#  '를',
#  '질',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '11',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '법',
#  '앞',
#  '에',
#  '평등',
#  '하',
#  '다',
#  '.',
#  '누구',
#  '든지',
#  '성별',
#  '·',
#  '종교',
#  '또는',
#  '사회적',
#  '신분',
#  '에',
#  '의하',
#  '여',
#  '정치적',
#  '·',
#  '경제적',
#  '·',
#  '사회적',
#  '·',
#  '문화적',
#  '생활',
#  '의',
#  '모든',
#  '영역',
#  '에',
#  '있',
#  '어서',
#  '차별',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '사회적',
#  '특수',
#  '계급',
#  '의',
#  '제도',
#  '는',
#  '인정',
#  '되',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '형태',
#  '로',
#  '도',
#  '이',
#  '를',
#  '창설',
#  '하',
#  'ㄹ',
#  '수',
#  '없',
#  '다',
#  '.',
#  '③',
#  '훈장',
#  '등',
#  '의',
#  '영전',
#  '은',
#  '이르',
#  'ㄹ',
#  '받',
#  '은',
#  '자',
#  '에게',
#  '만',
#  '효력',
#  '이',
#  '있',
#  '고',
#  ',',
#  '어떠하',
#  'ㄴ',
#  '특권',
#  '도',
#  '이에',
#  '따르',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '저',
#  '의',
#  '12',
#  '조',
#  '①',
#  '모든',
#  '국민',
#  '은',
#  '신체',
#  '의',
#  '자유',
#  '를',
#  '가지',
#  'ㄴ다',
#  '.',
#  '누구',
#  '든지',
#  '법률',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '·',
#  '수색',
#  '또는',
#  '심문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '법률',
#  '과',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '의하',
#  '지',
#  '아니하',
#  '고는',
#  '처벌',
#  '·',
#  '보안',
#  '처분',
#  '또는',
#  '강제',
#  '노역',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '②',
#  '모든',
#  '국민',
#  '은',
#  '고문',
#  '을',
#  '받',
#  '지',
#  '아니하',
#  '며',
#  ',',
#  '형',
#  '사상',
#  '자기',
#  '에게',
#  '불리',
#  '하',
#  'ㄴ',
#  '진술',
#  '을',
#  '강요',
#  '당하',
#  '지',
#  '아니하',
#  'ㄴ다',
#  '.',
#  '③',
#  '체포',
#  '·',
#  '구속',
#  '·',
#  '압수',
#  '또는',
#  '수색',
#  '을',
#  '하',
#  'ㄹ',
#  '때',
#  '에',
#  '는',
#  '적법',
#  '하',
#  'ㄴ',
#  '절차',
#  '에',
#  '따르',
#  '아',
#  '검사',
#  '의',
#  '신청',
#  '에',
#  '의하',
#  '여',
#  '법관',
#  '이',
#  '발부',
#  '하',
#  'ㄴ',
#  '영장',
#  '을',
#  '제시',
#  '하',
#  '여야',
#  '하',
#  'ㄴ다',
#  '.',
#  '다만',
#  ',',
#  '현행',
#  '범인',
#  '이',
#  'ㄴ',
#  '경우',
#  '와',
#  '장기',
#  '3',
#  '년',
#  '이상',
#  '의',
#  '형',
#  '에',
#  '해당',
#  '하',
#  '는',
#  '죄',
#  '를',
#  '범하',
#  '고',
#  '도피',
#  '또는',
#  '증거',
#  '인멸',
#  '의',
#  '염려',
#  '가',
#  '있',
#  '을',
#  '때',
#  '에',
#  '는',
#  ...]

# %%
wordList = [k for (k, v) in kkma.pos(corpus) if v.startswith('NN')]
wordList
# Out:
# ['대한민국',
#  '헌법',
#  '유구',
#  '역사',
#  '전통',
#  '우리',
#  '국민',
#  '운동',
#  '건립',
#  '대한민국',
#  '임시',
#  '정부',
#  '법통',
#  '불의',
#  '항거',
#  '민주',
#  '이념',
#  '계승',
#  '조국',
#  '민주',
#  '개혁',
#  '평화적',
#  '통일',
#  '사명',
#  '입각',
#  '정의',
#  '인도',
#  '동포애',
#  '민족',
#  '단결',
#  '사회적',
#  '폐습',
#  '불의',
#  '타파',
#  '자율',
#  '조화',
#  '바탕',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '정치',
#  '경제',
#  '사회',
#  '문화',
#  '영역',
#  '각인',
#  '기회',
#  '균등',
#  '히',
#  '능력',
#  '최고',
#  '도로',
#  '발휘',
#  '자유',
#  '권리',
#  '책임',
#  '의무',
#  '완수',
#  '안',
#  '국민',
#  '생활',
#  '균등',
#  '향상',
#  '밖',
#  '항구적',
#  '세계',
#  '평화',
#  '인류',
#  '공영',
#  '이바지',
#  '자손',
#  '안전',
#  '자유',
#  '행복',
#  '확보',
#  '것',
#  '다짐',
#  '년',
#  '월',
#  '일',
#  '제정',
#  '차',
#  '개정',
#  '헌법',
#  '이제',
#  '국회',
#  '의결',
#  '국민',
#  '투표',
#  '개정',
#  '장',
#  '강',
#  '제',
#  '대한민국',
#  '민주',
#  '공화국',
#  '대한민국',
#  '주권',
#  '국민',
#  '권력',
#  '국민',
#  '대한민국',
#  '국민',
#  '요건',
#  '법률',
#  '국가',
#  '법률',
#  '바',
#  '재외',
#  '국민',
#  '보호',
#  '의무',
#  '조',
#  '대한민국',
#  '영토',
#  '한반도',
#  '부속',
#  '조',
#  '대한민국',
#  '통일',
#  '지향',
#  '자유',
#  '민주적',
#  '기본',
#  '질서',
#  '입각',
#  '평화적',
#  '통일',
#  '정책',
#  '수립',
#  '추진',
#  '대한민국',
#  '국제',
#  '평화',
#  '유지',
#  '노력',
#  '침략',
#  '전쟁',
#  '부인',
#  '국',
#  '군은',
#  '국가',
#  '안전',
#  '보장',
#  '국토',
#  '방위',
#  '신성',
#  '의무',
#  '수행',
#  '사명',
#  '정치적',
#  '중립성',
#  '준수',
#  '헌법',
#  '체결',
#  '공포',
#  '조약',
#  '일반적',
#  '승인',
#  '국제',
#  '법규',
#  '국내',
#  '법과',
#  '효력',
#  '외국인',
#  '국제법',
#  '조약',
#  '바',
#  '지위',
#  '보장',
#  '공무원',
#  '국민',
#  '전체',
#  '봉사자',
#  '국민',
#  '책임',
#  '공무원',
#  '신분',
#  '정치적',
#  '중립성',
#  '법률',
#  '바',
#  '보장',
#  '정당',
#  '설립',
#  '자유',
#  '복수',
#  '정당제',
#  '보장',
#  '정당',
#  '목적',
#  '조직',
#  '활동',
#  '민주적',
#  '국민',
#  '정치적',
#  '의사',
#  '형성',
#  '참여',
#  '필요',
#  '조직',
#  '정당',
#  '법률',
#  '바',
#  '국가',
#  '보호',
#  '국가',
#  '법률',
#  '바',
#  '정당',
#  '운영',
#  '필요',
#  '자금',
#  '보조',
#  '수',
#  '정당',
#  '목적',
#  '활동',
#  '민주적',
#  '기본',
#  '질서',
#  '위배',
#  '때',
#  '정부',
#  '헌법',
#  '재판소',
#  '해산',
#  '제소',
#  '수',
#  '정당',
#  '헌법',
#  '재판소',
#  '심판',
#  '해산',
#  '조',
#  '국가',
#  '전통문화',
#  '계승',
#  '발전',
#  '민족',
#  '문화',
#  '창달',
#  '노력',
#  '장',
#  '국민',
#  '권리',
#  '의무',
#  '제',
#  '조',
#  '국민',
#  '인간',
#  '존엄',
#  '가치',
#  '행복',
#  '추구',
#  '권리',
#  '국가',
#  '개인',
#  '불가침',
#  '기본적',
#  '인권',
#  '확인',
#  '보장',
#  '의무',
#  '모든',
#  '국민',
#  '법',
#  '앞',
#  '평등',
#  '성별',
#  '종교',
#  '사회적',
#  '신분',
#  '정치적',
#  '경제적',
#  '사회적',
#  '문화적',
#  '생활',
#  '영역',
#  '차별',
#  '사회적',
#  '특수',
#  '계급',
#  '제도',
#  '인정',
#  '형태',
#  '창설',
#  '수',
#  '훈장',
#  '등',
#  '영전',
#  '자',
#  '효력',
#  '특권',
#  '모든',
#  '국민',
#  '신체',
#  '자유',
#  '법률',
#  '체포',
#  '구속',
#  '압수',
#  '수색',
#  '심문',
#  '법률',
#  '적법',
#  '절차',
#  '처벌',
#  '보안',
#  '처분',
#  '강제',
#  '노역',
#  '모든',
#  '국민',
#  '고문',
#  '형',
#  '사상',
#  '불리',
#  '진술',
#  '강요',
#  '체포',
#  '구속',
#  '압수',
#  '수색',
#  '때',
#  '적법',
#  '절차',
#  '검사',
#  '신청',
#  '법관',
#  '발부',
#  '영장',
#  '제시',
#  '현행',
#  '범인',
#  '경우',
#  '장기',
#  '년',
#  '이상',
#  '형',
#  '해당',
#  '죄',
#  '도피',
#  '증거',
#  '인멸',
#  '염려',
#  '때',
#  '사후',
#  '영장',
#  '청구',
#  '수',
#  '체포',
#  '구속',
#  '때',
#  '즉시',
#  '변호인',
#  '조력',
#  '권리',
#  '형사',
#  '피고인',
#  '변호인',
#  '수',
#  '때',
#  '법률',
#  '바',
#  '국가',
#  '변호인',
#  '체포',
#  '구속',
#  '이유',
#  '변호인',
#  '조력',
#  '권리',
#  '있음',
#  '고지',
#  '체포',
#  '구속',
#  '체포',
#  '구속',
#  '자의',
#  '가족',
#  '등',
#  '법률',
#  '자',
#  '이유',
#  '일시',
#  '장소',
#  '지체',
#  '통지',
#  '체포',
#  '구속',
#  '때',
#  '적부',
#  '심사',
#  '법원',
#  '청구',
#  '권리',
#  '피고인',
#  '자백',
#  '고문',
#  '폭행',
#  '협박',
#  '구속',
#  '부당',
#  '장기화',
#  '기망',
#  '기타',
#  '방법',
#  '자의',
#  '진술',
#  '것',
#  '인정',
#  '때',
#  '정식',
#  '재판',
#  '피고인',
#  '자백',
#  '불리',
#  '유일',
#  '증거',
#  '때',
#  '유죄',
#  '증거',
#  '이유',
#  '처벌',
#  '수',
#  '모든',
#  '국민',
#  '행위시',
#  '법률',
#  '범죄',
#  '구성',
#  '행위',
#  '소',
#  '추',
#  '동일',
#  '범죄',
#  '처벌',
#  '모든',
#  '국민',
#  '소급',
#  '입법',
#  '참정권',
#  '제한',
#  '재산권',
#  '박탈',
#  '모든',
#  '국민',
#  '행위',
#  '친족',
#  '행위',
#  '불',
#  '이익',
#  '처우',
#  '조',
#  '국민',
#  '거주',
#  '이전',
#  '자유',
#  '조',
#  '국민',
#  '직업',
#  '선택',
#  '자유',
#  '조',
#  '국민',
#  '주거',
#  '자유',
#  '침해',
#  '주거',
#  '압수',
#  '수색',
#  '때',
#  '검사',
#  '신청',
#  '법관',
#  '발부',
#  '영장',
#  '제시',
#  '조',
#  '국민',
#  '사생활',
#  '비밀',
#  '자유',
#  '침해',
#  '조',
#  '국민',
#  '통신',
#  '비밀',
#  '침해',
#  '조',
#  '국민',
#  '양심',
#  '자유',
#  '모든',
#  '국민',
#  '종교',
#  '자유',
#  '국교',
#  '인정',
#  '종교',
#  '정치',
#  '분리',
#  '모든',
#  '국민',
#  '언론',
#  '출판',
#  '자유',
#  '집회',
#  '결사',
#  '자유',
#  '언론',
#  '출판',
#  '허',
#  '검열',
#  '집회',
#  '결사',
#  '허가',
#  '인정',
#  '통신',
#  '방송',
#  '시설',
#  '기준',
#  '신문',
#  '기능',
#  '보장',
#  '필요',
#  '사항',
#  '법률',
#  '언론',
#  '출판',
#  '타인',
#  '명예',
#  '권리',
#  '공중',
#  '도덕',
#  '사회',
#  '윤리',
#  '침해',
#  '언론',
#  '출판',
#  '타인',
#  '명예',
#  '권리',
#  '침해',
#  '때',
#  '피해자',
#  '대',
#  '피해',
#  '배상',
#  '청구',
#  '수',
#  '모든',
#  '국민',
#  '학문',
#  '예술',
#  '자유',
#  '저작자',
#  '발명가',
#  '과학',
#  '기술자',
#  '예술가',
#  '권리',
#  '법률',
#  '보호',
#  '모든',
#  '국민',
#  '재산권',
#  '보장',
#  '내용',
#  '한계',
#  '법률',
#  '재산권',
#  '행사',
#  '공공',
#  '복리',
#  '적합',
#  '공공',
#  '필요',
#  '재산권',
#  '수용',
#  '사용',
#  '제한',
#  '보상',
#  '법률',
#  '정',
#  '보상',
#  '지급',
#  '조',
#  '국민',
#  '법률',
#  '바',
#  '선거권',
#  '조',
#  '국민',
#  '법률',
#  '바',
#  '공무',
#  '담임',
#  '모든',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '기관',
#  '문서',
#  '청원',
#  '권리',
#  '국가',
#  '청원',
#  '심사',
#  '의무',
#  '모든',
#  '국민',
#  '헌법',
#  '법률',
#  '법관',
#  '법률',
#  '재판',
#  '권리',
#  '군인',
#  '군무원',
#  '국민',
#  '대한민국',
#  '영역',
#  '안',
#  '중대',
#  '군',
#  '사상',
#  '기밀',
#  '초병',
#  '초소',
#  '음식물',
#  '공급',
#  '포로',
#  '군용물',
#  '죄',
#  '중',
#  '법률',
#  '경우',
#  '비상계엄',
#  '선포',
#  '경우',
#  '제외',
#  '군사',
#  '법원',
#  '재판',
#  '모든',
#  '국민',
#  '신속',
#  '재판',
#  '권리',
#  '형사',
#  '피고인',
#  '상당',
#  '이유',
#  '한',
#  '지체',
#  '공개',
#  '재판',
#  '권리',
#  '형사',
#  '피고인',
#  '유죄',
#  '판결',
#  '확정',
#  '때',
#  '무죄',
#  '추정',
#  '형사',
#  '피해자',
#  '법률',
#  '바',
#  '당해',
#  '사건',
#  '재판',
#  '절차',
#  '진술',
#  '수',
#  '조',
#  '형사',
#  '피의자',
#  '형사',
#  '피고인',
#  '구금',
#  '자가',
#  '법률',
#  '불기소',
#  '처분',
#  '무죄',
#  '판결',
#  '때',
#  '법률',
#  '바',
#  '국가',
#  '정',
#  '보상',
#  '청구',
#  '수',
#  '공무원',
#  '직무',
#  '불법',
#  '행위',
#  '손해',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '공공',
#  '단체',
#  '정',
#  '배상',
#  '청구',
#  '수',
#  '경우',
#  '공무원',
#  '자신',
#  '책임',
#  '면제',
#  '군인',
#  '군무원',
#  '경찰',
#  '공무원',
#  '기타',
#  '법률',
#  '자가',
#  '전투',
#  '훈련',
#  '등',
#  '직무',
#  '집행',
#  '관련',
#  '손해',
#  '법률',
#  '보상',
#  '외',
#  '국가',
#  '공공',
#  '단체',
#  '공무원',
#  '직무',
#  '불법',
#  '행위',
#  '배상',
#  '청구',
#  '수',
#  '조',
#  '타인',
#  '범죄',
#  '행위',
#  '생명',
#  '신체',
#  '피해',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '구조',
#  '수',
#  '모든',
#  '국민',
#  '능력',
#  '균등',
#  '교육',
#  '권리',
#  '모든',
#  '국민',
#  '보호',
#  '자녀',
#  '초등',
#  '교육',
#  '법률',
#  '교육',
#  '의무',
#  '의무',
#  '교육',
#  '무상',
#  '교육',
#  '자주성',
#  '전문',
#  '정치적',
#  '중립성',
#  '대학',
#  '자율성',
#  '법률',
#  '바',
#  '보장',
#  '국가',
#  '평생',
#  '교육',
#  '진흥',
#  '학교',
#  '교육',
#  '평생',
#  '교육',
#  '포함',
#  '교육',
#  '제도',
#  '운영',
#  '교육',
#  '재정',
#  '교원',
#  '지위',
#  '기본',
#  '적인',
#  '사항',
#  '법률',
#  '모든',
#  '국민',
#  '근로',
#  '권리',
#  '국가',
#  '사회적',
#  '경제적',
#  '방법',
#  '근로자',
#  '고용',
#  '증진',
#  '적정',
#  '임금',
#  '보장',
#  '노력',
#  '법률',
#  '바',
#  '최저',
#  '임금제',
#  '시행',
#  '모든',
#  '국민',
#  '근로',
#  '의무',
#  '국가',
#  '근로',
#  '의무',
#  '내용',
#  '조건',
#  '민주',
#  '주의',
#  '원칙',
#  '법률',
#  '근로',
#  '조건',
#  '기준',
#  '인간',
#  '존엄성',
#  '보장',
#  '법률',
#  '여자',
#  '근로',
#  '특별',
#  '보호',
#  '고용',
#  '임금',
#  '근로',
#  '조건',
#  '부당',
#  '차별',
#  '연소자',
#  '근로',
#  '특별',
#  '보호',
#  '국가',
#  '유공자',
#  '상이',
#  '군경',
#  '전몰',
#  '군경',
#  '유가족',
#  '법률',
#  '바',
#  '우선적',
#  '근로',
#  '기회',
#  '근로자',
#  '근로',
#  '조건',
#  '향상',
#  '자주적',
#  '단결권',
#  '단체',
#  '교섭권',
#  '단체',
#  '행동권',
#  '공무원',
#  '근로자',
#  '법률',
#  '자',
#  '단결권',
#  '단체',
#  '교섭권',
#  '단체',
#  '행동권',
#  '법률',
#  '주요',
#  '방위',
#  '산업체',
#  '종사',
#  '근로자',
#  '단체',
#  '행동권',
#  '법률',
#  '바',
#  '제한',
#  '인정',
#  '수',
#  '모든',
#  '국민',
#  '인간',
#  '생활',
#  '권리',
#  '국가',
#  '사회',
#  '보장',
#  '사회',
#  '복지',
#  '증진',
#  '노력',
#  '의무',
#  '국가',
#  '여자',
#  '복지',
#  '권익',
#  '향상',
#  '노력',
#  '국가',
#  '노인과',
#  '청소년',
#  '복',
#  '지향',
#  '정책',
#  '실시',
#  '의무',
#  '신체',
#  '장애자',
#  '질병',
#  '노령',
#  '기타',
#  '사유',
#  '생활',
#  '능력',
#  '국민',
#  '법률',
#  '바',
#  '국가',
#  '보호',
#  '국가',
#  '재해',
#  '예방',
#  '위험',
#  '국민',
#  '보호',
#  '노력',
#  '모든',
#  '국민',
#  '건강',
#  '환경',
#  '생활',
#  '권리',
#  '국가',
#  '국민',
#  '환경',
#  '보전',
#  '노력',
#  '환경권',
#  '내용',
#  '행사',
#  '법률',
#  '국가',
#  '주택',
#  '개발',
#  '정책',
#  '등',
#  '국민',
#  '주거',
#  '생활',
#  '수',
#  '노력',
#  '혼인',
#  '가족',
#  '생활',
#  '개인',
#  '존엄',
#  '양성',
#  '평등',
#  '기초',
#  '성립',
#  '유지',
#  '국가',
#  '보장',
#  '국가',
#  '모성',
#  '보호',
#  '노력',
#  '모든',
#  '국민',
#  '보건',
#  '국가',
#  '보호',
#  '국민',
#  ...]

# %% [markdown]
# 단어 리스트 중 명사만 뽑아냈다.

# %%
from collections import Counter

# %%
wordCount = Counter(wordList)
wordCount
# Out:
# Counter({'대한민국': 11,
#          '헌법': 69,
#          '유구': 1,
#          '역사': 1,
#          '전통': 1,
#          '우리': 1,
#          '국민': 69,
#          '운동': 3,
#          '건립': 1,
#          '임시': 3,
#          '정부': 23,
#          '법통': 1,
#          '불의': 2,
#          '항거': 1,
#          '민주': 6,
#          '이념': 1,
#          '계승': 2,
#          '조국': 3,
#          '개혁': 1,
#          '평화적': 4,
#          '통일': 9,
#          '사명': 2,
#          '입각': 2,
#          '정의': 2,
#          '인도': 1,
#          '동포애': 1,
#          '민족': 3,
#          '단결': 1,
#          '사회적': 5,
#          '폐습': 1,
#          '타파': 1,
#          '자율': 2,
#          '조화': 2,
#          '바탕': 1,
#          '자유': 21,
#          '민주적': 4,
#          '기본': 8,
#          '질서': 8,
#          '정치': 4,
#          '경제': 18,
#          '사회': 4,
#          '문화': 3,
#          '영역': 4,
#          '각인': 1,
#          '기회': 4,
#          '균등': 4,
#          '히': 1,
#          '능력': 3,
#          '최고': 3,
#          '도로': 1,
#          '발휘': 1,
#          '권리': 21,
#          '책임': 5,
#          '의무': 20,
#          '완수': 1,
#          '안': 15,
#          '생활': 8,
#          '향상': 4,
#          '밖': 1,
#          '항구적': 1,
#          '세계': 1,
#          '평화': 5,
#          '인류': 1,
#          '공영': 1,
#          '이바지': 1,
#          '자손': 1,
#          '안전': 11,
#          '행복': 2,
#          '확보': 1,
#          '것': 7,
#          '다짐': 1,
#          '년': 12,
#          '월': 3,
#          '일': 19,
#          '제정': 8,
#          '차': 3,
#          '개정': 9,
#          '이제': 1,
#          '국회': 55,
#          '의결': 16,
#          '투표': 8,
#          '장': 15,
#          '강': 1,
#          '제': 20,
#          '공화국': 1,
#          '주권': 2,
#          '권력': 1,
#          '요건': 1,
#          '법률': 121,
#          '국가': 73,
#          '바': 37,
#          '재외': 1,
#          '보호': 15,
#          '조': 58,
#          '영토': 2,
#          '한반도': 1,
#          '부속': 1,
#          '지향': 2,
#          '정책': 14,
#          '수립': 7,
#          '추진': 1,
#          '국제': 3,
#          '유지': 7,
#          '노력': 13,
#          '침략': 1,
#          '전쟁': 1,
#          '부인': 1,
#          '국': 21,
#          '군은': 1,
#          '보장': 24,
#          '국토': 3,
#          '방위': 2,
#          '신성': 1,
#          '수행': 4,
#          '정치적': 5,
#          '중립성': 3,
#          '준수': 2,
#          '체결': 4,
#          '공포': 11,
#          '조약': 11,
#          '일반적': 1,
#          '승인': 6,
#          '법규': 1,
#          '국내': 2,
#          '법과': 1,
#          '효력': 9,
#          '외국인': 1,
#          '국제법': 1,
#          '지위': 3,
#          '공무원': 17,
#          '전체': 1,
#          '봉사자': 1,
#          '신분': 3,
#          '정당': 14,
#          '설립': 1,
#          '복수': 1,
#          '정당제': 1,
#          '목적': 4,
#          '조직': 18,
#          '활동': 3,
#          '의사': 2,
#          '형성': 1,
#          '참여': 1,
#          '필요': 31,
#          '운영': 5,
#          '자금': 1,
#          '보조': 1,
#          '수': 88,
#          '위배': 3,
#          '때': 55,
#          '재판소': 14,
#          '해산': 5,
#          '제소': 3,
#          '심판': 12,
#          '전통문화': 1,
#          '발전': 5,
#          '창달': 2,
#          '인간': 3,
#          '존엄': 2,
#          '가치': 1,
#          '추구': 1,
#          '개인': 3,
#          '불가침': 1,
#          '기본적': 1,
#          '인권': 1,
#          '확인': 1,
#          '모든': 21,
#          '법': 6,
#          '앞': 2,
#          '평등': 4,
#          '성별': 1,
#          '종교': 3,
#          '경제적': 2,
#          '문화적': 1,
#          '차별': 2,
#          '특수': 1,
#          '계급': 1,
#          '제도': 5,
#          '인정': 8,
#          '형태': 1,
#          '창설': 1,
#          '훈장': 2,
#          '등': 6,
#          '영전': 3,
#          '자': 9,
#          '특권': 1,
#          '신체': 3,
#          '체포': 9,
#          '구속': 8,
#          '압수': 3,
#          '수색': 3,
#          '심문': 1,
#          '적법': 2,
#          '절차': 9,
#          '처벌': 3,
#          '보안': 1,
#          '처분': 12,
#          '강제': 1,
#          '노역': 1,
#          '고문': 2,
#          '형': 4,
#          '사상': 6,
#          '불리': 3,
#          '진술': 5,
#          '강요': 1,
#          '검사': 4,
#          '신청': 2,
#          '법관': 11,
#          '발부': 2,
#          '영장': 4,
#          '제시': 2,
#          '현행': 3,
#          '범인': 3,
#          '경우': 17,
#          '장기': 1,
#          '이상': 18,
#          '해당': 1,
#          '죄': 4,
#          '도피': 1,
#          '증거': 3,
#          '인멸': 1,
#          '염려': 2,
#          '사후': 1,
#          '청구': 6,
#          '즉시': 1,
#          '변호인': 4,
#          '조력': 2,
#          '형사': 6,
#          '피고인': 6,
#          '이유': 7,
#          '있음': 1,
#          '고지': 1,
#          '자의': 2,
#          '가족': 2,
#          '일시': 1,
#          '장소': 1,
#          '지체': 6,
#          '통지': 1,
#          '적부': 1,
#          '심사': 5,
#          '법원': 17,
#          '자백': 2,
#          '폭행': 1,
#          '협박': 1,
#          '부당': 2,
#          '장기화': 1,
#          '기망': 1,
#          '기타': 26,
#          '방법': 4,
#          '정식': 1,
#          '재판': 15,
#          '유일': 1,
#          '유죄': 2,
#          '행위시': 1,
#          '범죄': 4,
#          '구성': 8,
#          '행위': 8,
#          '소': 1,
#          '추': 1,
#          '동일': 1,
#          '소급': 1,
#          '입법': 2,
#          '참정권': 1,
#          '제한': 7,
#          '재산권': 4,
#          '박탈': 1,
#          '친족': 1,
#          '불': 2,
#          '이익': 5,
#          '처우': 2,
#          '거주': 1,
#          '이전': 2,
#          '직업': 1,
#          '선택': 1,
#          '주거': 3,
#          '침해': 6,
#          '사생활': 1,
#          '비밀': 4,
#          '통신': 2,
#          '양심': 3,
#          '국교': 1,
#          '분리': 1,
#          '언론': 5,
#          '출판': 5,
#          '집회': 12,
#          '결사': 3,
#          '허': 1,
#          '검열': 1,
#          '허가': 1,
#          '방송': 1,
#          '시설': 2,
#          '기준': 2,
#          '신문': 1,
#          '기능': 1,
#          '사항': 23,
#          '타인': 4,
#          '명예': 2,
#          '공중': 1,
#          '도덕': 1,
#          '윤리': 1,
#          '피해자': 2,
#          '대': 1,
#          '피해': 2,
#          '배상': 3,
#          '학문': 1,
#          '예술': 1,
#          '저작자': 1,
#          '발명가': 1,
#          '과학': 2,
#          '기술자': 1,
#          '예술가': 1,
#          '내용': 5,
#          '한계': 1,
#          '행사': 3,
#          '공공': 8,
#          '복리': 4,
#          '적합': 1,
#          '수용': 1,
#          '사용': 1,
#          '보상': 4,
#          '정': 5,
#          '지급': 1,
#          '선거권': 4,
#          '공무': 1,
#          '담임': 1,
#          '기관': 10,
#          '문서': 3,
#          '청원': 3,
#          '군인': 5,
#          '군무원': 3,
#          '중대': 5,
#          '군': 3,
#          '기밀': 1,
#          '초병': 2,
#          '초소': 2,
#          '음식물': 2,
#          '공급': 2,
#          '포로': 2,
#          '군용물': 1,
#          '중': 10,
#          '비상계엄': 2,
#          '선포': 4,
#          '제외': 5,
#          '군사': 10,
#          '신속': 1,
#          '상당': 1,
#          '한': 6,
#          '공개': 7,
#          '판결': 4,
#          '확정': 8,
#          '무죄': 2,
#          '추정': 1,
#          '당해': 1,
#          '사건': 1,
#          '피의자': 1,
#          '구금': 3,
#          '자가': 3,
#          '불기소': 1,
#          '직무': 19,
#          '불법': 2,
#          '손해': 2,
#          '단체': 16,
#          '자신': 1,
#          '면제': 2,
#          '경찰': 1,
#          '전투': 1,
#          '훈련': 1,
#          '집행': 4,
#          '관련': 2,
#          '외': 2,
#          '생명': 1,
#          '구조': 2,
#          '교육': 10,
#          '자녀': 1,
#          '초등': 1,
#          '무상': 1,
#          '자주성': 1,
#          '전문': 1,
#          '대학': 1,
#          '자율성': 1,
#          '평생': 2,
#          '진흥': 1,
#          '학교': 2,
#          '포함': 2,
#          '재정': 5,
#          '교원': 1,
#          '적인': 2,
#          '근로': 9,
#          '근로자': 4,
#          '고용': 2,
#          '증진': 3,
#          '적정': 2,
#          '임금': 2,
#          '최저': 1,
#          '임금제': 1,
#          '시행': 12,
#          '조건': 4,
#          '주의': 1,
#          '원칙': 2,
#          '존엄성': 1,
#          '여자': 2,
#          '특별': 6,
#          '연소자': 1,
#          '유공자': 1,
#          '상이': 1,
#          '군경': 2,
#          '전몰': 1,
#          '유가족': 1,
#          '우선적': 1,
#          '자주적': 1,
#          '단결권': 2,
#          '교섭권': 2,
#          '행동권': 3,
#          '주요': 1,
#          '산업체': 1,
#          '종사': 1,
#          '복지': 2,
#          '권익': 1,
#          '노인과': 1,
#          '청소년': 1,
#          '복': 1,
#          '실시': 3,
#          '장애자': 1,
#          '질병': 1,
#          '노령': 1,
#          '사유': 3,
#          '재해': 1,
#          '예방': 1,
#          '위험': 1,
#          '건강': 1,
#          '환경': 2,
#          '보전': 3,
#          '환경권': 1,
#          '주택': 1,
#          '개발': 6,
#          '혼인': 1,
#          '양성': 1,
#          '기초': 1,
#          '성립': 1,
#          '모성': 1,
#          '보건': 1,
#          '열거': 1,
#          '경시': 1,
#          '본질적': 1,
#          '납세': 1,
#          '국방': 2,
#          '병역': 1,
#          '이행': 2,
#          '입법권': 1,
#          '보통': 2,
#          '직접': 2,
#          '선거': 26,
#          '선출': 7,
#          '국회의원': 18,
#          '인': 9,
#          '선거구': 1,
#          '비례': 1,
#          '대표제': 1,
#          '임기': 18,
#          '직': 2,
#          '회기': 6,
#          '동의': 9,
#          '전': 6,
#          '요구': 13,
#          '석방': 1,
#          '행': 1,
#          '발언': 2,
#          '표결': 1,
#          '지지': 1,
#          '청렴': 1,
#          '우선': 1,
#          '남용': 2,
#          '기업체': 2,
#          '계약': 3,
#          '산상': 1,
#          '직위': 1,
#          '취득': 2,
#          '알선': 1,
#          '회의': 42,
#          '회': 1,
#          '임시회': 2,
#          '대통령': 84,
#          '재적': 14,
#          '의원': 23,
#          '분': 8,
#          '정기': 1,
#          '초과': 1,
#          '기간': 5,
#          '명시': 1,
#          '의장': 6,
#          '인과': 2,
#          '부의장': 1,
#          '규정': 6,
#          '과반수': 10,
#          '출석': 12,
#          '찬성': 12,
#          '가부': 1,
#          '동수': 1,
#          '부결': 1,
#          '하다': 2,
#          '공표': 1,
#          '제출': 8,
#          '법률안': 7,
#          '의안': 1,
#          '폐기': 1,
#          '만료': 3,
#          '이송': 2,
#          '이내': 6,
#          '이의': 2,
#          '항': 22,
#          '내': 2,
#          '서': 1,
#          '환부': 1,
#          '재의': 5,
#          '폐회': 1,
#          '일부': 1,
#          '수정': 1,
#          '수의': 1,
#          '전과': 1,
#          '후': 6,
#          '날': 2,
#          '경과': 1,
#          '발생': 2,
#          '예산안': 5,
#          '심의': 5,
#          '회계': 6,
#          '연도': 5,
#          '편성': 3,
#          '개시': 5,
#          '새': 1,
#          '예산': 5,
#          '안이': 1,
#          '다음': 4,
#          '경비': 3,
#          '전년도': 1,
#          '설치': 5,
#          '지출': 4,
#          '사업': 1,
#          '계속': 3,
#          '연한': 1,
#          '예비비': 2,
#          '총액': 1,
#          '차기': 1,
#          '변경': 3,
#          '추가': 1,
#          '경정': 1,
#          '항의': 1,
#          '금액': 1,
#          '증가': 1,
#          '비목': 1,
#          '국채': 1,
#          '모집': 1,
#          '예산외': 1,
#          '부담': 4,
#          '조세': 1,
#          '종목': 1,
#          '세율': 1,
#          '상호': 3,
#          '원조': 1,
#          '중요': 10,
#          '우호': 1,
#          '통상': 1,
#          '항해': 1,
#          '제약': 1,
#          '강화': 3,
#          '재정적': 1,
#          '비준': 2,
#          '동의권': 2,
#          '선전': 3,
#          '포고': 2,
#          '국군': 2,
#          '외국': 3,
#          '파견': 2,
#          '군대': 1,
#          '주류': 1,
#          '국정': 7,
#          '감사': 7,
#          '특정': 1,
#          '사안': 1,
#          '조사': 2,
#          '서류': 1,
#          '증인': 1,
#          '증언': 1,
#          '의견': 3,
#          '국무': 30,
#          '총리': 6,
#          '위원': 31,
#          '위원회': 7,
#          '처리': 6,
#          '상황': 2,
#          '질문': 1,
#          '응답': 1,
#          '국무총리': 13,
#          '답변': 2,
#          '해임': 3,
#          '건의': 3,
#          '발의': 4,
#          '저촉': 4,
#          '범위': 16,
#          '내부': 4,
#          '규율': 4,
#          '규칙': 6,
#          '자격': 6,
#          '징계': 2,
#          '제명': 1,
#          '행정': 15,
#          '각부': 9,
#          '재판관': 8,
#          '중앙': 3,
#          '관리': 13,
#          '감사원장': 2,
#          '탄핵': 11,
#          '소추': 5,
#          '결': 1,
#          '권한': 11,
#          '정지': 1,
#          '결정': 6,
#          '공직': 1,
#          '파면': 1,
#          '이': 11,
#          '민': 1,
#          '절': 3,
#          '원수': 1,
#          '대표': 1,
#          '독립': 2,
#          '계속성': 1,
#          '수호': 1,
#          '책무': 1,
#          '성실': 1,
#          '행정권': 1,
#          '수반': 1,
#          '득표자': 1,
#          '과반': 1,
#          '수가': 1,
#          '다수': 1,
#          '표': 1,
#          '당선': 2,
#          '자로': 1,
#          '후보자': 2,
#          '득표수': 1,
#          '총수': 1,
#          '피': 1,
#          '선거일': 1,
#          '현재': 1,
#          '세': 1,
#          '후임자': 4,
#          '궐': 2,
#          '위': 4,
#          '당선자': 1,
#          '사망': 1,
#          '상실': 2,
#          '취임': 1,
#          '즈음': 1,
#          '선서': 2,
#          '보위': 2,
#          '직책': 1,
#          '중임': 6,
#          '사고': 1,
#          '정한': 1,
#          '순서': 1,
#          '대행': 1,
#          '외교': 2,
#          '사절': 1,
#          '신임': 1,
#          '접수': 1,
#          '통수': 1,
#          '군의': 1,
#          '구체적': 1,
#          '위임': 3,
#          '대통령령': 3,
#          '내우': 1,
#          '외환': 2,
#          '천재': 1,
#          '지변': 1,
#          '상의': 4,
#          '위기': 1,
#          '안녕': 3,
#          '긴급': 4,
#          '조치': 3,
#          '여유': 1,
#          '최소한': 1,
#          '관': 5,
#          '명령': 9,
#          '안위': 1,
#          '관계': 4,
#          '교전': 1,
#          '상태': 1,
#          '불가능': 1,
#          '그때': 1,
#          '폐지': 1,
#          '회복': 1,
#          '전시': 1,
#          '사변': 1,
#          '비상사태': 1,
#          '병력': 1,
#          '계엄': 8,
#          '비상': 2,
#          '통고': 1,
#          '해제': 3,
#          '임면': 1,
#          '사면': 3,
#          '감형': 3,
#          '복권': 3,
#          '일반': 2,
#          '사': 1,
#          '수여': 2,
#          '서한': 1,
#          '표시': 1,
#          '국법': 1,
#          '부서': 1,
#          '공사': 1,
#          '내란': 1,
#          '재직': 1,
#          '전직': 1,
#          '예우': 1,
#          '행정부': 1,
#          '임명': 19,
#          '보좌': 2,
#          '명': 1,
#          '통할': 1,
#          '현역': 2,
#          '제청': 6,
#          '구성원': 1,
#          '이하': 2,
#          '부의': 1,
#          '계획': 5,
#          '대외': 3,
#          '개정안': 5,
#          '조약안': 1,
#          '결산': 3,
#          '국유': 2,
#          '재산': 2,
#          '간의': 2,
#          '획정': 1,
#          '정부안': 1,
#          '배정': 1,
#          '평가': 1,
#          '분석': 1,
#          '조정': 3,
#          '회부': 1,
#          '검찰': 1,
#          '총장': 3,
#          '합동': 1,
#          '참모': 2,
#          '국립대': 1,
#          '대사': 1,
#          '영기': 1,
#          '업체': 1,
#          '관리자': 1,
#          '자문': 12,
#          '원로': 4,
#          '직전': 2,
#          '지명': 3,
#          '주재': 1,
#          '소관': 1,
#          '사무': 8,
#          '직권': 1,
#          '총리령': 1,
#          '부령': 1,
#          '감사원': 5,
#          '세입': 2,
#          '세출': 2,
#          '감찰': 1,
#          '원장': 3,
#          '차년': 1,
#          '결과': 1,
#          '대상': 1,
#          '사법권': 1,
#          '원인': 1,
#          '대법원': 9,
#          '각급': 3,
#          '관의': 2,
#          '부': 1,
#          '대법관': 7,
#          '대법원장': 9,
#          '장의': 2,
#          '연임': 3,
#          '정년': 1,
#          '관은': 1,
#          '금고': 3,
#          '형의': 3,
#          '선고': 4,
#          '정직': 1,
#          '감봉': 1,
#          '관이': 1,
#          '심신': 1,
#          '장해': 1,
#          '퇴직': 1,
#          '위반': 2,
#          '여부': 3,
#          '전제': 2,
#          '최종적': 1,
#          '전심': 1,
#          '사법': 1,
#          '준용': 1,
#          '소송': 1,
#          '심리': 2,
#          '방해': 1,
#          '선량': 1,
#          '풍속': 1,
#          '관할': 2,
#          '상고심': 1,
#          '하의': 1,
#          '간첩죄': 1,
#          '단심': 1,
#          '사형': 1,
#          '관장': 1,
#          '위헌': 2,
#          '간': 4,
#          '지방': 9,
#          '자치': 9,
#          '쟁의': 1,
#          '소원': 2,
#          '인의': 2,
#          '관중': 2,
#          '인은': 2,
#          '가입': 2,
#          '관여': 2,
#          '인용': 1,
#          '공정': 1,
#          '위원장': 1,
#          '호선': 1,
#          '원의': 1,
#          '법령': 3,
#          '급': 2,
#          '선거인': 1,
#          '명부': 1,
#          '작성': 1,
#          '지시': 2,
#          '당': 1,
#          '주민': 1,
#          '종류': 1,
#          '의회': 2,
#          '선임': 4,
#          '기업': 2,
#          '창의': 1,
#          '존중': 1,
#          '균형': 5,
#          '성장': 1,
#          '안정': 2,
#          '소득': 1,
#          '분배': 1,
#          '시장': 1,
#          '지배': 1,
#          '경제력': 1,
#          '방지': 1,
#          '주체': 1,
#          '민주화': 1,
#          '규제': 2,
#          '광물': 1,
#          '지하': 1,
#          '자원': 3,
#          '수산': 1,
#          '수력': 1,
#          '이용': 5,
#          '자연력': 1,
#          '일정': 1,
#          '채취': 1,
#          '특허': 1,
#          '농지': 4,
#          '경자': 1,
#          '유전': 1,
#          '달성': 2,
#          '소작': 1,
#          '금지': 1,
#          '농업': 2,
#          '생산성': 1,
#          '제고': 1,
#          '합리': 1,
#          '사정': 1,
#          '임대차': 1,
#          '위탁': 1,
#          '경영': 2,
#          '모두': 1,
#          '생산': 1,
#          '기반': 1,
#          '효율적': 1,
#          '어업': 1,
#          '육성': 5,
#          '농': 3,
#          '어촌': 1,
#          '종합': 1,
#          '지원': 1,
#          '지역': 2,
#          '중소기업': 2,
#          '농수산물': 1,
#          '수급': 1,
#          '유통': 1,
#          '개선': 1,
#          '가격': 1,
#          '도모': 1,
#          '어민': 2,
#          '자조': 1,
#          '건전': 1,
#          '소비': 1,
#          '계도': 1,
#          '생산품': 1,
#          '품질': 1,
#          '촉구': 1,
#          '소비자': 1,
#          '무역': 1,
#          '국방상': 1,
#          '사영': 1,
#          '공유': 1,
#          '통제': 1,
#          '기술': 1,
#          '혁신': 1,
#          '정보': 1,
#          '인력': 1,
#          '표준': 1,
#          '확립': 1,
#          '기구': 1,
#          '제안': 3,
#          '연장': 1,
#          '당시': 6,
#          '공고': 2,
#          '투표자': 1,
#          '침': 1,
#          '부칙': 2,
#          '호': 1,
#          '보기': 1,
#          '준비': 1,
#          '최초': 7,
#          '일로': 3,
#          '전일': 2,
#          '임원': 1,
#          '임명권': 1,
#          '전임자': 1,
#          '판사': 1,
#          '단서': 1,
#          '적용': 1,
#          '지속': 1,
#          '존속': 1})

# %%
type(wordCount)
# Out:
# collections.Counter

# %% [markdown]
# 추려낸 명사들이 corpus 내에서 몇번 나왔는지 count하여 Counter 객체로 저장.

# %%
wordCount = wordCount.most_common(40)
wordCount
# Out:
# [('법률', 121),
#  ('수', 88),
#  ('대통령', 84),
#  ('국가', 73),
#  ('헌법', 69),
#  ('국민', 69),
#  ('조', 58),
#  ('국회', 55),
#  ('때', 55),
#  ('회의', 42),
#  ('바', 37),
#  ('필요', 31),
#  ('위원', 31),
#  ('국무', 30),
#  ('기타', 26),
#  ('선거', 26),
#  ('보장', 24),
#  ('정부', 23),
#  ('사항', 23),
#  ('의원', 23),
#  ('항', 22),
#  ('자유', 21),
#  ('권리', 21),
#  ('국', 21),
#  ('모든', 21),
#  ('의무', 20),
#  ('제', 20),
#  ('일', 19),
#  ('직무', 19),
#  ('임명', 19),
#  ('경제', 18),
#  ('조직', 18),
#  ('이상', 18),
#  ('국회의원', 18),
#  ('임기', 18),
#  ('공무원', 17),
#  ('경우', 17),
#  ('법원', 17),
#  ('의결', 16),
#  ('단체', 16)]

# %% [markdown]
# 가장 많이 등장한 40개의 단어만 추려 list로 저장했다.

# %%
import pytagcloud
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tagList = pytagcloud.make_tags(wordCount, maxsize=40)
tagList
# Out:
# [{'color': (124, 63, 84), 'size': 44, 'tag': '법률'},
#  {'color': (132, 129, 138), 'size': 35, 'tag': '수'},
#  {'color': (81, 183, 68), 'size': 33, 'tag': '대통령'},
#  {'color': (12, 197, 16), 'size': 30, 'tag': '국가'},
#  {'color': (131, 139, 101), 'size': 29, 'tag': '헌법'},
#  {'color': (207, 205, 24), 'size': 29, 'tag': '국민'},
#  {'color': (146, 152, 200), 'size': 26, 'tag': '조'},
#  {'color': (107, 83, 12), 'size': 25, 'tag': '국회'},
#  {'color': (134, 172, 40), 'size': 25, 'tag': '때'},
#  {'color': (220, 43, 102), 'size': 20, 'tag': '회의'},
#  {'color': (208, 179, 130), 'size': 19, 'tag': '바'},
#  {'color': (89, 129, 27), 'size': 16, 'tag': '필요'},
#  {'color': (202, 189, 96), 'size': 16, 'tag': '위원'},
#  {'color': (141, 123, 106), 'size': 16, 'tag': '국무'},
#  {'color': (134, 205, 114), 'size': 15, 'tag': '기타'},
#  {'color': (138, 20, 176), 'size': 15, 'tag': '선거'},
#  {'color': (103, 153, 152), 'size': 14, 'tag': '보장'},
#  {'color': (175, 135, 194), 'size': 13, 'tag': '정부'},
#  {'color': (41, 201, 106), 'size': 13, 'tag': '사항'},
#  {'color': (112, 115, 26), 'size': 13, 'tag': '의원'},
#  {'color': (209, 161, 61), 'size': 13, 'tag': '항'},
#  {'color': (143, 31, 18), 'size': 13, 'tag': '자유'},
#  {'color': (22, 92, 17), 'size': 13, 'tag': '권리'},
#  {'color': (168, 76, 61), 'size': 13, 'tag': '국'},
#  {'color': (31, 99, 76), 'size': 13, 'tag': '모든'},
#  {'color': (28, 58, 75), 'size': 12, 'tag': '의무'},
#  {'color': (127, 139, 209), 'size': 12, 'tag': '제'},
#  {'color': (181, 109, 87), 'size': 12, 'tag': '일'},
#  {'color': (117, 99, 16), 'size': 12, 'tag': '직무'},
#  {'color': (171, 199, 181), 'size': 12, 'tag': '임명'},
#  {'color': (82, 54, 144), 'size': 12, 'tag': '경제'},
#  {'color': (190, 193, 70), 'size': 12, 'tag': '조직'},
#  {'color': (151, 211, 44), 'size': 12, 'tag': '이상'},
#  {'color': (184, 22, 102), 'size': 12, 'tag': '국회의원'},
#  {'color': (102, 52, 126), 'size': 12, 'tag': '임기'},
#  {'color': (123, 108, 140), 'size': 11, 'tag': '공무원'},
#  {'color': (173, 89, 171), 'size': 11, 'tag': '경우'},
#  {'color': (185, 205, 15), 'size': 11, 'tag': '법원'},
#  {'color': (183, 108, 167), 'size': 11, 'tag': '의결'},
#  {'color': (118, 24, 111), 'size': 11, 'tag': '단체'}]

# %%
pytagcloud.create_tag_image(tagList, 'cloud.jpg', fontname='Nanum')

# %% [markdown]
# 분석한 빈도에 비례하게 글자 크기를 조절하여 Wordcloud 생성후 저장.
